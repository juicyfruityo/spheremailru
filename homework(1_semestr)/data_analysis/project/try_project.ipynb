# %%
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
plt.rcParams['figure.figsize'] = 8, 5

# %%
df = pd.read_csv('Video_Games_Sales_as_at_22_Dec_2016.csv')

# %%
df.head(5)
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# ...

# %%
df.groupby(by='Rating')['Global_Sales'].sum()
# Out:
# Rating
# AO         1.95
# E       2436.90
# E10+     655.81
# EC         1.78
# K-A        4.33
# M       1473.84
# RP         0.08
# T       1494.40
# Name: Global_Sales, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
# Name               16717 non-null object
# Platform           16719 non-null object
# Year_of_Release    16450 non-null float64
# Genre              16717 non-null object
# Publisher          16665 non-null object
# NA_Sales           16719 non-null float64
# EU_Sales           16719 non-null float64
# JP_Sales           16719 non-null float64
# Other_Sales        16719 non-null float64
# Global_Sales       16719 non-null float64
# Critic_Score       8137 non-null float64
# Critic_Count       8137 non-null float64
# User_Score         10015 non-null object
# User_Count         7590 non-null float64
# Developer          10096 non-null object
# Rating             9950 non-null object
# dtypes: float64(9), object(7)
# memory usage: 2.0+ MB

# %%
df.describe()
# Out:
#        Year_of_Release      NA_Sales      EU_Sales      JP_Sales  \
# count     16450.000000  16719.000000  16719.000000  16719.000000
# mean       2006.487356      0.263330      0.145025      0.077602
# std           5.878995      0.813514      0.503283      0.308818
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2020.000000     41.360000     28.960000     10.220000
#
#         Other_Sales  Global_Sales  Critic_Score  Critic_Count    User_Count
# count  16719.000000  16719.000000   8137.000000   8137.000000   7590.000000
# mean       0.047332      0.533543     68.967679     26.360821    162.229908
# std        0.186710      1.547935     13.938165     18.980495    561.282326
# min        0.000000      0.010000     13.000000      3.000000      4.000000
# ...

# %%
df[(df['Publisher'] == 'Activision') & (df['Year_of_Release'] == 2000.0)]
# Out:
#                                                    Name Platform  \
# 227                            Tony Hawk's Pro Skater 2       PS
# 438                                          Spider-Man       PS
# 781                              Tony Hawk's Pro Skater      N64
# 1471                             Tony Hawk's Pro Skater       GB
# 3213                     Buzz Lightyear of Star Command       PS
# 3476           Tenchu 2: Birth of the Stealth Assassins       PS
# 3784                                         Spider-Man      N64
# 4260                              Star Wars: Demolition       PS
# 5820                           Orphen: Scion of Sorcery      PS2
# 6475                                Star Trek: Invasion       PS
# 7610                                    Disney's Tarzan      N64
# 8795   Disney's The Lion King: Simba's Mighty Adventure       PS
# 10202                          Vigilante 8: 2nd Offense      N64
#
# ...

# %%
df[df['Publisher'] == 'Activision'].groupby(by='Year_of_Release')['Global_Sales'].sum().sort_values(ascending=False)
# Out:
# Year_of_Release
# 2009.0    77.14
# 2008.0    66.86
# 2007.0    63.30
# 2010.0    62.67
# 2012.0    52.17
# 2011.0    50.93
# 2014.0    44.40
# 2013.0    42.75
# 2004.0    39.23
# 2015.0    35.87
# 2005.0    35.35
# 2002.0    25.94
# 2003.0    21.37
# 2001.0    18.59
# 2006.0    17.30
# 2000.0    14.48
# 2016.0    12.48
# 1981.0     8.50
# 1999.0     7.57
# 1998.0     7.54
# 1995.0     4.21
# 1980.0     3.02
# 1997.0     2.55
# 1994.0     2.08
# 1996.0     1.95
# 1983.0     1.94
# 1982.0     1.86
# 1987.0     1.12
# 1988.0     0.75
# 1985.0     0.48
# 1989.0     0.47
# 1984.0     0.27
# Name: Global_Sales, dtype: float64

# %%
df.shape
# Out:
# (16719, 16)

# %%
df.groupby(by='Publisher')['Global_Sales'].sum().sort_values(ascending=False)
# Out:
# Publisher
# Nintendo                                  1788.81
# Electronic Arts                           1116.96
# Activision                                 731.16
# Sony Computer Entertainment                606.48
# Ubisoft                                    471.61
# Take-Two Interactive                       403.82
# THQ                                        338.44
# Konami Digital Entertainment               282.39
# Sega                                       270.35
# Namco Bandai Games                         254.62
# Microsoft Game Studios                     248.32
# Capcom                                     200.02
# Atari                                      156.83
# Warner Bros. Interactive Entertainment     151.79
# Square Enix                                144.35
# Disney Interactive Studios                 117.37
# Eidos Interactive                           98.65
# LucasArts                                   85.83
# Bethesda Softworks                          85.05
# ...

# %%
df_publ_devel = df[df['Publisher'] != df['Developer']].dropna()

# %%
df_publ_devel.groupby(by='Publisher')['Global_Sales'].sum().sort_values(ascending=False)[:15]
# Out:
# Publisher
# Electronic Arts                           812.42
# Activision                                532.53
# Sony Computer Entertainment               388.10
# Take-Two Interactive                      349.52
# Nintendo                                  319.59
# Ubisoft                                   245.70
# Microsoft Game Studios                    212.03
# THQ                                       155.13
# Konami Digital Entertainment              137.87
# Sega                                      133.59
# Namco Bandai Games                        109.33
# Warner Bros. Interactive Entertainment    108.53
# Atari                                      82.00
# Bethesda Softworks                         70.60
# Square Enix                                66.21
# Name: Global_Sales, dtype: float64

# %%
df_publ_devel[df['Publisher'] == 'Electronic Arts']['Developer']
# Out:
# /home/Albert/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 77                     EA Sports
# 85               The Sims Studio
# 94       EA Sports, EA Vancouver
# 101                      EA DICE
# 102                 EA Black Box
# 104                      EA DICE
# 113                    EA Canada
# 114                        EA LA
# 126                    EA Canada
# 143                    EA Sports
# 177                   SquareSoft
# 193                        EA LA
# 202                    EA Sports
# 213                    EA Sports
# 228           Stormfront Studios
# 238                   EA Tiburon
# 241                    EA Sports
# 253                    EA Canada
# 271                    EA Canada
# 274                    EA Canada
# 283                    EA Sports
# 289                      EA DICE
# ...

# %%
df = df.drop(df[df['Year_of_Release'] > 2016.0].index)

# %%
sales
# Out:
# Publisher
# Nintendo                        1788.81
# Electronic Arts                 1116.96
# Activision                       731.16
# Sony Computer Entertainment      606.48
# Ubisoft                          471.32
# Take-Two Interactive             403.82
# THQ                              338.44
# Konami Digital Entertainment     282.39
# Sega                             270.30
# Namco Bandai Games               254.62
# Name: Global_Sales, dtype: float64

# %%
sales.plot(kind='bar')

# %%
x
# Out:
# Electronic Arts                 1356
# Activision                       985
# Namco Bandai Games               939
# Ubisoft                          932
# Konami Digital Entertainment     834
# THQ                              715
# Nintendo                         706
# Sony Computer Entertainment      687
# Sega                             636
# Take-Two Interactive             422
# Name: Publisher, dtype: int64

# %%
# посмотрим сколько выпусков у какой компании 

x = df['Publisher'].value_counts()[:10]
# x_other = df['Publisher'].value_counts()[10:].sum()
# df['Publisher'].value_counts().sum()

plt.rcParams['font.size'] = 13 

fig = plt.figure(figsize=(12,6))

ax = x.plot.bar(rot=70, width=0.4)
ax.annotate('Top 10 компаний = 8215 (' + str(round(8210/16650 * 100)) + "%)" + '\n'
            + 'Другие компании = 8450 (' + str(round(8450/16650 * 100)) + "%)",
            xy=(4,1100))
ax.set_title('Количество выпущенных игр')
# Out:
# Text(0.5,1,'Количество выпущенных игр')

# %%
print(df.groupby(by='Publisher')['Global_Sales'].sum().sort_values(ascending=False)[:10].sum())
print(df.groupby(by='Publisher')['Global_Sales'].sum().sort_values(ascending=False).sum())
# Out:
# 6264.299999999981
# 8905.149999999981

# %%
round(2641 / 8905 * 100)
# Out:
# 30

# %%
sales = df.groupby(by='Publisher')['Global_Sales'].sum().sort_values(ascending=False)[:10]
fig = plt.figure(figsize=(12,6))
ax = sales.plot(kind='bar', rot=70)
ax.annotate('Top 10 команий = 6264 (70%) \n'
            + 'Другие компании = 2641 (30%)', xy=(4, 1200))
ax.set_title('Количество проданных копий')
# Out:
# Text(0.5,1,'Количество проданных копий')

# %%
# рассмотрим коммпании поближе 
x = df[df['Publisher'] == 'Nintendo']['Year_of_Release'].value_counts().sort_index()
# plt.plot()
plt.plot(x)

# %%
#посмотрим вцелмо продажи по годам и выпуски игр по годам

games = df['Year_of_Release'].value_counts().sort_index()
sales = df.groupby(by='Year_of_Release')['Global_Sales'].sum()

# %%
sales
# Out:
# Year_of_Release
# 1980.0     11.38
# 1981.0     35.77
# 1982.0     28.86
# 1983.0     16.79
# 1984.0     50.36
# 1985.0     53.94
# 1986.0     37.07
# 1987.0     21.74
# 1988.0     47.22
# 1989.0     73.45
# 1990.0     49.39
# 1991.0     32.23
# 1992.0     76.17
# 1993.0     48.40
# 1994.0     79.18
# 1995.0     88.11
# 1996.0    199.15
# 1997.0    200.98
# 1998.0    256.45
# 1999.0    251.25
# 2000.0    201.58
# 2001.0    331.47
# 2002.0    395.51
# 2003.0    357.80
# 2004.0    419.05
# 2005.0    458.31
# 2006.0    518.22
# 2007.0    605.37
# 2008.0    671.79
# 2009.0    658.88
# 2010.0    590.59
# 2011.0    507.79
# 2012.0    355.84
# 2013.0    361.24
# 2014.0    331.51
# 2015.0    268.05
# 2016.0    130.10
# Name: Global_Sales, dtype: float64

# %%
fig = plt.figure(figsize= (14,5))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)

ax1.plot(games)
ax1.set_title('Количество выпущенных игр')
ax2.plot(sales)
ax2.set_title('Количество проданных копий')

ax1.annotate('', xy=(2015, 630), xytext=(2015, 800),
            arrowprops=dict(facecolor='black'),
            )
ax2.annotate('', xy=(2015, 300), xytext=(2015, 400),
            arrowprops=dict(facecolor='black'),
            )
# Out:
# Text(2015,400,'')

# %%
games
# Out:
# 2008.0    1427
# 2009.0    1426
# 2010.0    1255
# 2007.0    1197
# 2011.0    1136
# 2006.0    1006
# 2005.0     939
# 2002.0     829
# 2003.0     775
# 2004.0     762
# 2012.0     653
# 2015.0     606
# 2014.0     581
# 2013.0     544
# 2016.0     502
# 2001.0     482
# 1998.0     379
# 2000.0     350
# 1999.0     338
# 1997.0     289
# 1996.0     263
# 1995.0     219
# 1994.0     121
# 1993.0      62
# 1981.0      46
# 1992.0      43
# 1991.0      41
# 1982.0      36
# 1986.0      21
# 1989.0      17
# 1983.0      17
# 1990.0      16
# 1987.0      16
# 1988.0      15
# 1985.0      14
# 1984.0      14
# 1980.0       9
# Name: Year_of_Release, dtype: int64

# %%
df.head(3)
# Out:
#                 Name Platform  Year_of_Release     Genre Publisher  NA_Sales  \
# 0         Wii Sports      Wii           2006.0    Sports  Nintendo     41.36
# 1  Super Mario Bros.      NES           1985.0  Platform  Nintendo     29.08
# 2     Mario Kart Wii      Wii           2008.0    Racing  Nintendo     15.68
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  Critic_Count  \
# 0     28.96      3.77         8.45         82.53          76.0          51.0
# 1      3.58      6.81         0.77         40.24           NaN           NaN
# 2     12.76      3.79         3.29         35.52          82.0          73.0
#
#   User_Score  User_Count Developer Rating
# 0          8       322.0  Nintendo      E
# 1        NaN         NaN       NaN    NaN
# 2        8.3       709.0  Nintendo      E

# %%
df_corr = df.drop(['Name', 'Platform', 'Genre', 'Publisher',
                   'Developer', 'Rating', 'Critic_Count'], axis=1)
fig = plt.figure(figsize= (14,7))
sns.heatmap(df_corr.dropna().corr(), 
            xticklabels = df_corr.columns.values,
            yticklabels = df_corr.columns.values, 
            cmap = 'Blues')

# %%
plt.figure(figsize=(13,6))
sns.heatmap(df_corr.corr(), 
            xticklabels = df_corr.columns.values,
            yticklabels = df_corr.columns.values,
            annot = True);

# %%
df['User_Score'] = pd.to_numeric(df['User_Score'], errors='coerce')

# %%
ax = sns.jointplot(x='User_Score', y='Critic_Score', data=df, color='red', kind = 'hex')
sns.regplot(df.User_Score, df.Critic_Score, ax=ax.ax_joint, scatter=False, color='red')
# Out:
# /home/Albert/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /home/Albert/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
# Будем искать развивающиеся компании
# анализивроавть эти компании и думать можно ли к ним ворваться

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly
import plotly.graph_objs as go

init_notebook_mode(connected=True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
sales = pd.DataFrame(df.groupby(by='Publisher')['Global_Sales'].sum().sort_values(ascending=False))

# %%
sales.head(5)
# Out:
#                              Global_Sales
# Publisher
# Nintendo                          1788.81
# Electronic Arts                   1116.96
# Activision                         731.16
# Sony Computer Entertainment        606.48
# Ubisoft                            471.32

# %%
relese = pd.DataFrame(data=df['Publisher'].value_counts())

# %%
len(df['Publisher'].value_counts())
# Out:
# 581

# %%
relese.columns = ['Games']

# %%
data = {'Publisher': df.Publisher.unique(), 'Sales': }
df_comp = pd.DataFrame(data=data)

# %%
df_comp.head(5)
# Out:
#                      Publisher
# 0                     Nintendo
# 1       Microsoft Game Studios
# 2         Take-Two Interactive
# 3  Sony Computer Entertainment
# 4                   Activision

# %%
res = pd.merge(df_comp, sales, on='Publisher')

# %%
res.head(5)
# Out:
#                      Publisher  Global_Sales
# 0                     Nintendo       1788.81
# 1       Microsoft Game Studios        248.32
# 2         Take-Two Interactive        403.82
# 3  Sony Computer Entertainment        606.48
# 4                   Activision        731.16

# %%
df['Publisher'].value_counts()

# %%
relese = relese.rename(columns={'Publisher': 'Games'})
relese['Publisher'] = relese.index

# %%
df_companies = pd.merge(res, relese, on='Publisher')
df_companies['sale_per_game'] = df_companies.Global_Sales / df_companies.Games

# %%
df_companies = df_companies.sort_values(by='sale_per_game', ascending=False)

# %%
trace = go.Bar(
    x=df_companies['Publisher'][:15],
    y=df_companies['sale_per_game'][:15],
    marker=dict(
        color=df_companies['sale_per_game'][:15],
        colorscale = 'Reds')
)

trace_table = go.Table(
    header=dict(values=df_companies.columns,
                fill = dict(color='#F0C2C2')),
    cells=dict(values=[df_companies.Publisher[:15], df_companies.Global_Sales[:15],
                       df_companies['Games'][:15], df_companies.sale_per_game[:15]],
               fill = dict(color='#F8E2E2'),
               height=40),
    domain=dict(x=[0, 1],
                y=[0, 1]))

data = [trace]
layout = go.Layout(
    title='Top компании по количеству продаж на одну игру'
)

fig = go.Figure(data=data, layout=layout)
iplot(fig)

data = [trace_table]
fig = go.Figure(data=data)
iplot(fig)
# Out:
# <div id="35d07ce5-15ae-477e-8b3e-0c4d6d4dc81a" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("35d07ce5-15ae-477e-8b3e-0c4d6d4dc81a", [{"marker": {"color": [4.17, 2.62, 2.533725212464586, 2.36, 2.25, 2.17, 1.7, 1.7, 1.5580000000000003, 1.55, 1.3001047120418854, 1.205, 1.2, 1.1300000000000001, 1.1246666666666658], "colorscale": "Reds"}, "x": ["Palcom", "Red Orb", "Nintendo", "Arena Entertainment", "UEP Systems", "RedOctane", "Hello Games", "Valve", "Sony Computer Entertainment Europe", "Westwood Studios", "Microsoft Game Studios", "Imagic", "Black Label Games", "Maxis", "Enix Corporation"], "y": [4.17, 2.62, 2.533725212464586, 2.36, 2.25, 2.17, 1.7, 1.7, 1.5580000000000003, 1.55, 1.3001047120418854, 1.205, 1.2, 1.1300000000000001, 1.1246666666666658], "type": "bar", "uid": "3e448f62-2fe5-4f10-9df4-5
# ...

# %%
comp = (df.Publisher == 'Palcom') | (df.Publisher == 'Red Orb')
df[(df.Publisher == 'Palcom') | (df.Publisher == 'Red Orb')]
# Out:
#                              Name Platform  Year_of_Release      Genre  \
# 279  Teenage Mutant Ninja Turtles      NES           1989.0     Action
# 521                          Myst       PC           1994.0  Adventure
# 637     Riven: The Sequel to Myst       PC           1997.0  Adventure
#
#     Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 279    Palcom      3.38      0.44      0.31         0.04          4.17
# 521   Red Orb      0.02      2.79      0.00         0.00          2.81
# 637   Red Orb      1.52      0.82      0.00         0.10          2.43
#
#      Critic_Score  Critic_Count  User_Score  User_Count    Developer Rating
# 279           NaN           NaN         NaN         NaN          NaN    NaN
# 521           NaN           NaN         NaN         NaN          NaN    NaN
# 637          83.0          12.0         NaN         NaN  Cyan Worlds      E

# %%
df[comp]
# Out:
#                              Name Platform  Year_of_Release      Genre  \
# 279  Teenage Mutant Ninja Turtles      NES           1989.0     Action
# 521                          Myst       PC           1994.0  Adventure
# 637     Riven: The Sequel to Myst       PC           1997.0  Adventure
#
#     Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 279    Palcom      3.38      0.44      0.31         0.04          4.17
# 521   Red Orb      0.02      2.79      0.00         0.00          2.81
# 637   Red Orb      1.52      0.82      0.00         0.10          2.43
#
#      Critic_Score  Critic_Count  User_Score  User_Count    Developer Rating
# 279           NaN           NaN         NaN         NaN          NaN    NaN
# 521           NaN           NaN         NaN         NaN          NaN    NaN
# 637          83.0          12.0         NaN         NaN  Cyan Worlds      E

# %%
# какие области захватили большие компании

# %%
df_top = pd.DataFrame(df.groupby(by='Publisher')['Global_Sales'].sum().sort_values(ascending=False)[:20])
df_middle = pd.DataFrame(df.groupby(by='Publisher')['Global_Sales'].sum().sort_values(ascending=False)[20:320])

# %%
df_top.index[0]
# Out:
# 'Nintendo'

# %%
df_top = df.loc[df.Publisher.isin(df_top.index)]
df_middle = df.loc[df.Publisher.isin(df_middle.index)]
df_top
# Out:
#                                                     Name Platform  \
# 0                                             Wii Sports      Wii
# 1                                      Super Mario Bros.      NES
# 2                                         Mario Kart Wii      Wii
# 3                                      Wii Sports Resort      Wii
# 4                               Pokemon Red/Pokemon Blue       GB
# 5                                                 Tetris       GB
# 6                                  New Super Mario Bros.       DS
# 7                                               Wii Play      Wii
# 8                              New Super Mario Bros. Wii      Wii
# 9                                              Duck Hunt      NES
# 10                                            Nintendogs       DS
# 11                                         Mario Kart DS       DS
# 12                           Pokemon Gold/Pokemon Silver       GB
# ...

# %%
df_top_genre = pd.DataFrame(df_top.groupby(by='Genre')['Global_Sales'].sum().sort_values(ascending=False))
df_top_genre
# Out:
#               Global_Sales
# Genre
# Action             1526.46
# Sports             1191.81
# Shooter             959.33
# Platform            758.49
# Role-Playing        744.24
# Misc                657.16
# Racing              600.99
# Fighting            369.55
# Simulation          314.03
# Puzzle              194.36
# Adventure           170.66
# Strategy            135.10

# %%
df_middle_genre = pd.DataFrame(df_middle.groupby(by='Genre')['Global_Sales'].sum().sort_values(ascending=False))
df_middle_genre.columns
# Out:
# Index(['Global_Sales'], dtype='object')

# %%
df_together = pd.merge(df_top_genre, df_middle_genre, on='Genre')
df_together['Percent'] = df_together.Global_Sales_y / df_together.Global_Sales_x
df_together
# Out:
#               Global_Sales_x  Global_Sales_y   Percent
# Genre
# Action               1526.46          215.56  0.141216
# Sports               1191.81          136.24  0.114314
# Shooter               959.33           91.56  0.095442
# Platform              758.49           68.56  0.090390
# Role-Playing          744.24          187.82  0.252365
# Misc                  657.16          135.21  0.205749
# Racing                600.99          127.13  0.211534
# Fighting              369.55           73.95  0.200108
# Simulation            314.03           74.40  0.236920
# Puzzle                194.36           47.39  0.243826
# Adventure             170.66           63.17  0.370151
# Strategy              135.10           37.64  0.278608

# %%
trace1 = go.Bar(
    x=df_top_genre.index,
    y=df_top_genre.Global_Sales,
    name='Global Sales by top20'
)

trace2 = go.Bar(
    x=df_middle_genre.index,
    y=df_middle_genre.Global_Sales,
    name='Global Sales by middle companies')

trace_table = go.Table(
    header=dict(values=['Genre', 'Percent']),
    cells=dict(values=[df_together.index, df_together.Percent],
               height=40),
    domain=dict(x=[0.5, 1],
                y=[0.5, 1]))

data = [trace1, trace2, trace_table]

fig = go.Figure(data=data)
iplot(fig, show_link=False)
# Out:
# <div id="54b090b6-8ef7-4c9c-a02d-a977f70823e7" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("54b090b6-8ef7-4c9c-a02d-a977f70823e7", [{"name": "Global Sales by top20", "x": ["Action", "Sports", "Shooter", "Platform", "Role-Playing", "Misc", "Racing", "Fighting", "Simulation", "Puzzle", "Adventure", "Strategy"], "y": [1526.4599999999866, 1191.8099999999883, 959.3299999999983, 758.4899999999985, 744.2399999999978, 657.1599999999983, 600.9899999999989, 369.5499999999995, 314.029999999999, 194.36000000000016, 170.66000000000037, 135.10000000000036], "type": "bar", "uid": "2688fa5c-3d13-4995-aef1-41f9563d0b9a"}, {"name": "Global Sales by middle companies", "x": ["Action", "Role-Playing", "Sports", "Misc", "Racing", "Shooter", "Simulation", "Fighting", "Platform", "Adventure", "Puzzle", "Strategy"], "y"
# ...

# %%
df_middle_time = pd.DataFrame(df_middle.groupby('Year_of_Release')['Global_Sales'].sum().sort_index(ascending=False))
df_top_time = pd.DataFrame(df_top.groupby('Year_of_Release')['Global_Sales'].sum().sort_index(ascending=False))

# %%
trace1 = go.Scatter(
    x=df_middle_time.index,
    y=df_middle_time.Global_Sales,
    name='Global Sales by middle companies'
)

trace2 = go.Scatter(
    x=df_top_time.index,
    y=df_top_time.Global_Sales,
    name='Global Sales by middle companies'
)

layout = {'title': 'Global Sales'}
data = [trace1, trace2]

fig = go.Figure(data=data, layout=layout)
iplot(fig, show_link=False)
# Out:
# <div id="1744febf-823a-4004-986f-b597581de806" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("1744febf-823a-4004-986f-b597581de806", [{"name": "Global Sales by middle companies", "x": [2016.0, 2015.0, 2014.0, 2013.0, 2012.0, 2011.0, 2010.0, 2009.0, 2008.0, 2007.0, 2006.0, 2005.0, 2004.0, 2003.0, 2002.0, 2001.0, 2000.0, 1999.0, 1998.0, 1997.0, 1996.0, 1995.0, 1994.0, 1993.0, 1992.0, 1991.0, 1990.0, 1989.0, 1988.0, 1987.0, 1986.0, 1985.0, 1984.0, 1983.0, 1982.0, 1981.0], "y": [14.46999999999996, 27.16000000000004, 31.280000000000033, 37.550000000000075, 28.660000000000014, 61.170000000000165, 67.24999999999983, 85.80999999999997, 73.80000000000008, 64.2500000000003, 36.95000000000008, 33.48000000000003, 46.50000000000002, 58.43999999999998, 63.60000000000005, 55.150000000000055, 40.03000000000001, 6
# ...

# %%
df_middle_jp = df_middle.JP_Sales.sum()
df_top_jp = df_top.JP_Sales.sum()
df_top_na = df_top.NA_Sales.sum()
df_middle_na = df_middle.NA_Sales.sum()
df_top_eu = df_top.EU_Sales.sum()
df_middle_eu = df_middle.EU_Sales.sum()
df_middle_oth = df_middle.Other_Sales.sum()
df_top_oth = df_top.Other_Sales.sum()

# %%
trace1 = go.Pie(labels=['Top20', 'Middle comp.'], 
               values=[df_top_jp, df_middle_jp],
               domain=dict(x=[0.45, 1],
                           y=[0.45, 1]),
               name='Продажи в Японии'
               #marker=dict(colors=colors)
              )
trace2 = go.Pie(labels=['Top20', 'Middle comp.'], 
               values=[df_top_na, df_middle_na],
               domain=dict(x=[0, 0.55],
                           y=[0.45, 1]),
               name='Продажи в Северной Америке'
               #marker=dict(colors=colors)
              )
trace3 = go.Pie(labels=['Top20', 'Middle comp.'], 
               values=[df_top_eu, df_middle_eu],
               domain=dict(x=[0.22, 0.77],
                           y=[0, 0.55]),
               name='Продажи в Европе'
               #marker=dict(colors=colors)
              )
trace4 = go.Pie(labels=['Top20', 'Middle comp.'], 
               values=[df_top_oth, df_middle_oth],
               domain=dict(x=[0.8, 1],
                           y=[0, 0.3]),
               name='Продажи в других местах'
               #marker=dict(colors=colors)
              )


data = [trace1, trace2, trace3, trace4]

fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <div id="81aee010-5f88-4e6d-ad84-31612b57f3a0" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("81aee010-5f88-4e6d-ad84-31612b57f3a0", [{"domain": {"x": [0.45, 1], "y": [0.45, 1]}, "labels": ["Top20", "Middle comp."], "name": "\u041f\u0440\u043e\u0434\u0430\u0436\u0438 \u0432 \u042f\u043f\u043e\u043d\u0438\u0438", "values": [990.1999999999999, 297.38], "type": "pie", "uid": "9a88b652-5421-4718-b9a2-5a0760567011"}, {"domain": {"x": [0, 0.55], "y": [0.45, 1]}, "labels": ["Top20", "Middle comp."], "name": "\u041f\u0440\u043e\u0434\u0430\u0436\u0438 \u0432 \u0421\u0435\u0432\u0435\u0440\u043d\u043e\u0439 \u0410\u043c\u0435\u0440\u0438\u043a\u0435", "values": [3799.97, 586.77], "type": "pie", "uid": "48c8f8fe-6750-4b24-8c6c-6b23c30e1a1b"}, {"domain": {"x": [0.22, 0.77], "y": [0, 0.55]}, "labels": ["Top20
# ...

# %%
df.head(5)
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count  User_Score  User_Count Developer Rating
# ...

# %%
df[df.Name == 'Grand Theft Auto: San Andreas']
# Out:
#                                 Name Platform  Year_of_Release   Genre  \
# 17     Grand Theft Auto: San Andreas      PS2           2004.0  Action
# 875    Grand Theft Auto: San Andreas       XB           2005.0  Action
# 2115   Grand Theft Auto: San Andreas       PC           2005.0  Action
# 10312  Grand Theft Auto: San Andreas     X360           2008.0  Action
#
#                   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 17     Take-Two Interactive      9.43      0.40      0.41        10.57
# 875    Take-Two Interactive      1.26      0.61      0.00         0.09
# 2115   Take-Two Interactive      0.00      0.93      0.00         0.04
# 10312  Take-Two Interactive      0.08      0.02      0.00         0.01
#
#        Global_Sales  Critic_Score  Critic_Count User_Score  User_Count  \
# 17            20.81          95.0          80.0          9      1588.0
# 875            1.95          93.0          58.0        8.6       118.0
# ...

# %%
df[df.Name == 'Grand Theft Auto V']
# Out:
#                     Name Platform  Year_of_Release   Genre  \
# 16    Grand Theft Auto V      PS3           2013.0  Action
# 23    Grand Theft Auto V     X360           2013.0  Action
# 42    Grand Theft Auto V      PS4           2014.0  Action
# 165   Grand Theft Auto V     XOne           2014.0  Action
# 1730  Grand Theft Auto V       PC           2015.0  Action
#
#                  Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 16    Take-Two Interactive      7.02      9.09      0.98         3.96
# 23    Take-Two Interactive      9.66      5.14      0.06         1.41
# 42    Take-Two Interactive      3.96      6.31      0.38         1.97
# 165   Take-Two Interactive      2.81      2.19      0.00         0.47
# 1730  Take-Two Interactive      0.39      0.69      0.00         0.09
#
#       Global_Sales  Critic_Score  Critic_Count User_Score  User_Count  \
# 16           21.04          97.0          50.0        8.2      3994.0
# ...

# %% [markdown]
# будем пытаться применять статистические критерии
#
# проверим Nintendo и EA людят одинаково?

# %%
df_Nintendo = df[df.Publisher == 'Nintendo'].dropna()
df_EA = df[df.Publisher == 'Electronic Arts']

# %%
df_nin_score = pd.DataFrame(df_Nintendo.User_Score.value_counts().sort_index(ascending=False))
plt.plot(df_nin_score.index, df_nin_score.User_Score)

# %%
import numpy as np
from scipy import stats
distr_nin = np.array(df_Nintendo.User_Score.value_counts().sort_index(ascending=False))

stats.shapiro(distr_nin) # не нормальное распределение
# Out:
# (0.8431495428085327, 1.7149108316516504e-05)

# %%
distr_ea = np.array(df_EA.User_Score.value_counts().sort_index(ascending=False))
stats.shapiro(distr_ea)
# Out:
# (0.7166180610656738, 5.654557724832365e-11)

# %%
df_nin_sales = pd.DataFrame(df_Nintendo.groupby(by='Year_of_Release')['Global_Sales'].sum().sort_index(ascending=False))
plt.plot(df_nin_sales.index, df_nin_sales.Global_Sales)

distr_nin = np.array(df_Nintendo.groupby(by='Year_of_Release')['Global_Sales'].sum().sort_index(ascending=False))

stats.shapiro(distr_nin) # не подходит тоже
# Out:
# (0.8200283050537109, 0.005088504403829575)

# %% [markdown]
# PS так же популярна в свое время как X360 в своё?

# %%
df_ps = df[df.Platform == 'PS']['Year_of_Release'].value_counts().sort_index(ascending=False)
df_ps = np.array(df_ps)
stats.shapiro(df_ps) # ура номральное распределение
# Out:
# (0.9260306358337402, 0.41000327467918396)

# %%
df_ps2 = df[df.Platform == 'PS2']['Year_of_Release'].value_counts().sort_index(ascending=False)
df_ps2 = np.array(df_ps2)
stats.shapiro(df_ps2) # увы не номральное распределение
# Out:
# (0.8650533556938171, 0.05658377334475517)

# %%
df_ps2 = pd.DataFrame(df[df.Platform == 'PS2']['Year_of_Release'].value_counts().sort_index(ascending=False))
plt.plot(df_ps2.index, df_ps2.Year_of_Release)

# %%
df.Platform.unique()
# Out:
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        'PS4', '3DS', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne',
#        'WiiU', 'GC', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)

# %%
df_x360 = df[df.Platform == 'X360']['Year_of_Release'].value_counts().sort_index(ascending=False)
df_x360 = np.array(df_x360)
stats.shapiro(df_x360) # ура номральное распределение
# Out:
# (0.955607533454895, 0.7197787761688232)

# %%
df_x = pd.DataFrame(df[df.Platform == 'X360']['Year_of_Release'].value_counts().sort_index(ascending=False))
plt.plot(df_x.index, df_x.Year_of_Release)

# %%
df_p = pd.DataFrame(df[df.Platform == 'PS']['Year_of_Release'].value_counts().sort_index(ascending=False))
plt.plot(df_p.index, df_p.Year_of_Release)

# %%
df_x = pd.DataFrame(df[df.Platform == 'XB']['Year_of_Release'].value_counts().sort_index(ascending=False))
plt.plot(df_x.index, df_x.Year_of_Release)

# %%
stats.ttest_ind(df_ps, df_x360)
# Out:
# Ttest_indResult(statistic=0.507909485369489, pvalue=0.6170727656473012)

# %%
df_ps4 = df[df.Platform == 'PS4']['Year_of_Release'].value_counts().sort_index(ascending=False)
df_ps4 = np.array(df_ps4)
df_xone = df[df.Platform == 'XOne']['Year_of_Release'].value_counts().sort_index(ascending=False)
df_xone = np.array(df_xone)

stats.ttest_ind(df_ps4, df_xone)
# Out:
# Ttest_indResult(statistic=0.43392648133284123, pvalue=0.6774015811276891)

# %%
df_ps4 = df[df.Platform == 'PS4'].groupby(by='Year_of_Release')['Global_Sales'].sum().sort_index(ascending=False)
df_xone = df[df.Platform == 'XOne'].groupby(by='Year_of_Release')['Global_Sales'].sum().sort_index(ascending=False)
stats.ttest_ind(df_ps4, df_xone)
# Out:
# Ttest_indResult(statistic=0.8601609069392215, pvalue=0.41818318829101664)

# %%
df.Platform.unique()
# Out:
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        'PS4', '3DS', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne',
#        'WiiU', 'GC', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)

# %%
df_ = df[df.Platform == 'PSP'].groupby(by='Year_of_Release')['Global_Sales'].sum().sort_index(ascending=False)
df_ = np.array(df_)
stats.shapiro(df_)
# Out:
# (0.8916162848472595, 0.12363353371620178)

# %%
df_xone = pd.DataFrame(df[df.Platform == 'XOne'].groupby(by='Year_of_Release')
                       ['Global_Sales'].sum().sort_index(ascending=False))
df_ps4 = pd.DataFrame(df[df.Platform == 'PS4'].groupby(by='Year_of_Release')
                      ['Global_Sales'].sum().sort_index(ascending=False))

# %%
trace1 = go.Scatter(
    x=df_xone.index,
    y=df_xone.Global_Sales,
    name='Global Sales by XboxOne'
)

trace2 = go.Scatter(
    x=df_ps4.index,
    y=df_ps4.Global_Sales,
    name='Global Sales by PS4'
)

layout = {'title': 'Global Sales'}
data = [trace1, trace2]

fig = go.Figure(data=data, layout=layout)
iplot(fig, show_link=False)
# Out:
# <div id="7a19d656-9b01-42f4-ba54-f88a7b4e19a8" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("7a19d656-9b01-42f4-ba54-f88a7b4e19a8", [{"name": "Global Sales by XboxOne", "x": [2016.0, 2015.0, 2014.0, 2013.0], "y": [26.27000000000002, 60.09000000000002, 54.139999999999986, 18.94], "type": "scatter", "uid": "ef7c66fe-6657-421f-aa67-d43b111ad85a"}, {"name": "Global Sales by PS4", "x": [2017.0, 2016.0, 2015.0, 2014.0, 2013.0], "y": [0.04, 69.29000000000002, 118.96000000000001, 99.96999999999996, 25.97], "type": "scatter", "uid": "79c70ec1-547e-4e61-835b-c5e7a541a986"}], {"title": "Global Sales"}, {"showLink": false, "linkText": "Export to plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("7a19d656-9b01-
# ...

# %% [markdown]
# Оценим одинаково ли часто критики и игроки ставят высокие оценки играм Electronic Arts с помощью критерия хи квадрат

# %%
df_ea = df[df.Publisher == 'Electronic Arts']

df_ea
# Out:
#                                                     Name Platform  \
# 77                                               FIFA 16      PS4
# 81                                        FIFA Soccer 13      PS3
# 85                                            The Sims 3       PC
# 87                          Star Wars Battlefront (2015)      PS4
# 94                                               FIFA 17      PS4
# 101                                        Battlefield 3     X360
# 102                           Need for Speed Underground      PS2
# 104                                        Battlefield 3      PS3
# 113                         Need for Speed Underground 2      PS2
# 114                            Medal of Honor: Frontline      PS2
# 122                                              FIFA 12      PS3
# 126                                              FIFA 14      PS3
# 143                                              FIFA 15      PS4
# ...

# %%
df['User_Score'] = pd.to_numeric(df['User_Score'], errors='coerce')

more80_critic = len(df_ea[df.Critic_Score >= 80])
less80_critic = len(df_ea[df.Critic_Score < 80])

more8_user = len(df_ea[df.User_Score >= 8.0])
less8_user = len(df_ea[df.User_Score < 8.0])

total = more80_critic + less80_critic + more8_user + less8_user

df_ea_matr = pd.DataFrame({'больше 8.0': [more80_critic, more8_user, more80_critic+more8_user],
                           'меньше 8.0': [less80_critic, less8_user, less80_critic+less8_user],
                           'всего': [more80_critic+less80_critic, more8_user+less8_user, total]},
                         index=['Критики', 'Игроки', 'Вместе'])
df_ea_matr
# Out:
# /home/Albert/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# /home/Albert/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# /home/Albert/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# /home/Albert/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#          больше 8.0  меньше 8.0  всего
# Критики         417         612   1029
# Игроки          321         705   1026
# Вместе          738        1317   2055

# %%
from scipy.stats import chi2_contingency
chi2_contingency(df_ea_matr.iloc[:2,:2])
# Out:
# (18.651384888052966,
#  1.5693323987536103e-05,
#  1,
#  array([[369.53868613, 659.46131387],
#         [368.46131387, 657.53868613]]))

# %%
df_ea_matr.iloc[:2, :2].plot.bar(stacked=True)

# %% [markdown]
# Activision VS Sony четатам

# %%
df_activision = np.array(df[df.Publisher == 'Activision']['User_Score'].value_counts().sort_index(ascending=False))
df_sony = np.array(df[df.Publisher == 'Sony Computer Entertainment'].User_Score.value_counts().sort_index(ascending=False))

# %%
x = pd.DataFrame(df_activision.value_counts().sort_index(ascending=False))
plt.plot(x)
stats.shapiro(x)
# Out:
# (0.9447759985923767, 0.032314449548721313)

# %%
stats.mannwhitneyu(df_activision, df_sony)
# Out:
# MannwhitneyuResult(statistic=1513.5, pvalue=0.02666065432172212)

# %%
df_act = pd.DataFrame(df[df.Publisher == 'Activision']['User_Score'].value_counts().sort_index(ascending=False))

# %%
df_so = pd.DataFrame(df[df.Publisher == 'Sony Computer Entertainment']['User_Score'].value_counts().sort_index(ascending=False))

# %%
trace1 = go.Scatter(
    x=df_act.index,
    y=df_act.User_Score,
    name='Global Sales by middle companies'
)

trace2 = go.Scatter(
    x=df_so.index,
    y=df_so.User_Score,
    name='Global Sales by middle companies'
)

layout = {'title': 'Global Sales'}
data = [trace1, trace2]

fig = go.Figure(data=data, layout=layout)
iplot(fig, show_link=False)
# Out:
# <div id="8bb26466-f23f-4748-8a8d-329f191ff003" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("8bb26466-f23f-4748-8a8d-329f191ff003", [{"name": "Global Sales by middle companies", "x": [9.4, 9.3, 9.2, 9.1, 9.0, 8.9, 8.8, 8.7, 8.6, 8.5, 8.4, 8.3, 8.2, 8.1, 8.0, 7.9, 7.8, 7.7, 7.6, 7.5, 7.4, 7.3, 7.2, 7.1, 7.0, 6.9, 6.8, 6.7, 6.6, 6.5, 6.4, 6.3, 6.2, 6.1, 6.0, 5.9, 5.8, 5.7, 5.6, 5.5, 5.4, 5.3, 5.2, 5.1, 5.0, 4.9, 4.8, 4.7, 4.6, 4.5, 4.4, 4.3, 4.2, 4.1, 4.0, 3.8, 3.7, 3.6, 3.5, 3.4, 3.3, 3.2, 3.1, 3.0, 2.8, 2.6, 2.5, 2.4, 2.1, 2.0, 1.8, 1.5, 1.4], "y": [1, 4, 4, 7, 8, 6, 13, 12, 11, 13, 11, 15, 11, 9, 22, 12, 22, 12, 21, 25, 13, 14, 14, 8, 16, 11, 9, 11, 12, 11, 15, 15, 9, 11, 7, 5, 7, 8, 12, 7, 6, 7, 10, 4, 12, 2, 6, 2, 3, 8, 4, 2, 3, 2, 5, 2, 3, 2, 3, 7, 1, 1, 5, 3, 3, 3, 1, 1, 2, 3, 1, 1, 1], "typ
# ...

# %%
print(len(df[df.Publisher == 'Activision']))
len(df[df.Publisher == 'Sony Computer Entertainment'])
# Out:
# 985
# 687

# %% [markdown]
# Временной ряд продаж Bethesda?

# %%
df_beth_hist = df.groupby(by='Year_of_Release')['Global_Sales'].sum().sort_index()

# %%
plt.plot(df_beth_hist)

# %%
df_ps_history = df[(df.Platform == 'PS') | (df.Platform == 'PS2') | \
                   (df.Platform == 'PS3') | (df.Platform == 'PS4')] \
                  ['Year_of_Release'].value_counts().sort_index(ascending=False)

# %%
plt.plot(df_ps_history)

# %%
df_ps_history = df[(df.Platform == 'PS') | (df.Platform == 'PS2') | \
                   (df.Platform == 'PS3') | (df.Platform == 'PS4')] \
                  ['Year_of_Release'].value_counts().sort_index()

df_ps_history = pd.DataFrame(df_ps_history).iloc[:-1, :]
df_ps_history
# Out:
#         Year_of_Release
# 1994.0               17
# 1995.0               99
# 1996.0              164
# 1997.0              188
# 1998.0              248
# 1999.0              200
# 2000.0              242
# 2001.0              276
# 2002.0              300
# 2003.0              259
# 2004.0              259
# 2005.0              260
# 2006.0              286
# 2007.0              304
# 2008.0              329
# 2009.0              258
# 2010.0              219
# 2011.0              222
# 2012.0              148
# 2013.0              142
# 2014.0              183
# 2015.0              210
# 2016.0              202

# %%
import statsmodels.api as sm

stat_test = sm.tsa.adfuller(df_ps_history.Year_of_Release)
print ('adf: ', stat_test[0] )
print ('p-value: ', stat_test[1])
print('Critical values: ', stat_test[4])
if stat_test[0]> stat_test[4]['5%']: 
    print ('есть единичные корни, ряд не стационарен')
else:
    print ('единичных корней нет, ряд стационарен')
# Out:
# adf:  -3.4413164302135484
# p-value:  0.009628491378581709
# Critical values:  {'1%': -3.769732625845229, '5%': -3.005425537190083, '10%': -2.6425009917355373}
# единичных корней нет, ряд стационарен

# %%
train_ps_history = df_ps_history.Year_of_Release.diff(periods=1).dropna()

# %%
print(len(train_ps_history))
plt.plot(train_ps_history)
# Out:
# 22

# %%
stat_test = sm.tsa.adfuller(train_ps_history)
print ('adf: ', stat_test[0] )
print ('p-value: ', stat_test[1])
print('Critical values: ', stat_test[4])
if stat_test[0]> stat_test[4]['5%']: 
    print ('есть единичные корни, ряд не стационарен')
else:
    print ('единичных корней нет, ряд стационарен')
# Out:
# adf:  -3.966180361771426
# p-value:  0.0015983303399970813
# Critical values:  {'1%': -3.7883858816542486, '5%': -3.013097747543462, '10%': -2.6463967573696143}
# единичных корней нет, ряд стационарен

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(train_ps_history.values.squeeze(), lags=20, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(train_ps_history, lags=25, ax=ax2)

# %%
d = 0 # т.к. diff(1)
D = 0

q = 1 #0
Q = 0

P = 1 #1
p = 1 #0

s = 5

# %%
best_model=sm.tsa.statespace.SARIMAX(df_ps_history.Year_of_Release.squeeze(), order=(p, d, q), 
                                        seasonal_order=(P, D, Q, s)).fit()
# Out:
# /home/Albert/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:221: ValueWarning:
#
# An unsupported index was provided and will be ignored when e.g. forecasting.

# %%
y_hat = pd.DataFrame()
forecast = best_model.predict(start = df_ps_history.shape[0], end = df_ps_history.shape[0]+3)
forecast
# Out:
# /home/Albert/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.
# 23    204.782514
# 24    199.205225
# 25    187.032482
# 26    177.057350
# dtype: float64

# %%
# df_ps_history.index = pd.to_numeric(df_ps_history.index, downcast='integer')
# df_ps_history.index = pd.to_datetime(df_ps_history.index,format='%Y')
df_ps_history['date'] = df_ps_history.index
df_ps_history.index = range(23)

# %%
np.array(df_ps_history.Year_of_Release)
# Out:
# array([202, 210, 183, 142, 148, 222, 219, 258, 329, 304, 286, 260, 259,
#        259, 300, 276, 242, 200, 248, 188, 164,  99,  17])
